# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("test.jpg")
img.shape
# Out:
# (400, 604)

# %%
plt.imshow(img, cmap='gray')

# %%
mask = (np.random.random(img.shape) > 0.2)*1

# %%
maskedimg = img * mask
plt.imshow(maskedimg, cmap='gray')
